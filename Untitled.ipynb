# %%
import cv2
import os
#os.environ['CUDA_VISIBLE_DEVICES'] = "0"
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import time
face = cv2.CascadeClassifier('haar cascade files\haarcascade_frontalface_alt.xml')
leye = cv2.CascadeClassifier('haar cascade files\haarcascade_lefteye_2splits.xml')
reye = cv2.CascadeClassifier('haar cascade files\haarcascade_righteye_2splits.xml')

# %%
image = cv2.imread("pic1.png")
image2 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image2)

# %%
grayscale = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
gray = cv2.cvtColor(grayscale, cv2.COLOR_BGR2RGB)
plt.imshow(gray)

# %%
faces = face.detectMultiScale(gray,minNeighbors=5,scaleFactor=1.1,minSize=(25,25))
for (x,y,w,h) in faces:
    cv2.rectangle(image2, (x,y) , (x+w,y+h) , (100,100,100) , 1 )
plt.imshow(image2)

# %%
left_eye = leye.detectMultiScale(gray)
right_eye = reye.detectMultiScale(gray)

# %%
for (x,y,w,h) in right_eye:
    r_eye=image2[y:y+h,x:x+w]
    cv2.rectangle(image2, (x, y), (x + w, y + h), (100, 100, 100), 1)
plt.imshow(image2)

# %%
import visualkeras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

classes = 4

model = Sequential()
model.add(Conv2D(32, (3,3), padding = 'same', input_shape = (256,256,1), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(64, (3,3), padding = 'same', activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(128,(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2))) 

model.add(Flatten())

model.add(Dense(64, activation = 'relu'))

model.add(Dense(classes, activation = 'softmax'))

print(model.summary())
visualkeras.layered_view(model,to_file='model_plot2.png',legend=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 256, 256, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 64)                8388672
#
#  dense_1 (Dense)             (None, 4)                 260
#
# ...
# Total params: 8,481,604
# Trainable params: 8,481,604
# Non-trainable params: 0
# _________________________________________________________________
# None
# <PIL.Image.Image image mode=RGBA size=834x1402>

# %%
from keras.utils.vis_utils import plot_model
plot_model(model,to_file='model_plot.png', show_shapes=True, show_layer_names=True)
